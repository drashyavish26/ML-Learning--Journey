# %%
print("drashya ")
# Out:
# drashya

# %%
#indexing
str= "drashya vishwakarma"
cha=str[1]
print(cha)
print(str[2])
print(str[7])
# Out:
# r
# a

# %%
#slicing
str="drashya vishwakarma"
print(str[0:7])
print(str[8:19])
print(str[8:len(str)])
print(str[8:])#[8:end of string]
print(str[:7])#[0:7]
# Out:
# drashya
# vishwakarma
# vishwakarma
# vishwakarma
# drashya

# %%
#negative indexing
str="apple"
print(str[-4:-1])
str="drashya vishwakarma"
print(str[-11:])
print(str[-2])
# Out:
# ppl
# vishwakarma
# m

# %%
#functions
#endswith
str="drashya vishwakarma"
print(str.endswith("ma"))
print(str.endswith("maa"))

#capitalize
print(str.capitalize())#only works one time 
print(str)

str2="drashya vishwakarma"
str2=str.capitalize()
print(str2)


#REPLACE FUNCTION
str="drashya vishwakarma"
print(str.replace("a", "z"))
print(str.replace("drashya", "abhi"))


#find fumction
str="drashya vishwakarma from ichhawar "
print(str.find("m"))
print(str.find("d"))
print(str.find("drashya"))
print(str.find("vishwakarma"))
print(str.find("zz"))#always returns -1 when word is not present

#COUNT FUNCTION
print(str.count("from"))
print(str.count("a"))
# Out:
# True
# False
# Drashya vishwakarma
# drashya vishwakarma
# Drashya vishwakarma
# drzshyz vishwzkzrmz
# abhi vishwakarma
# 17
# 0
# 0
# 8
# -1
# 1
# 7

# %%
#practice questions
name=input("enter name")
print("length of your name is ", len(name))
# Out:
# length of your name is  0

# %%
#conditional statements

age=21
if(True):
    print("can vote and apply for licence")
    if(False):#always cpital T & F for  using booleans 
        print("cannot vote ")

    if(age >=18):
        print("can vote and apply for licence")
# Out:
# can vote and apply for licence
# can vote and apply for licence
